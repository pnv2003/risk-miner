# %%
import pandas as pd

issuelinks = pd.read_csv("./apache/issuelinks.csv")
issuelinks.head()
# Out:
#             key  issuelink.id   type.id  type.name          type.inward  \
# 0    XALANC-524         11181     10020    Cloners         is cloned by
# 1       MNG-309      12414097  12310260    Related        is related to
# 2       MNG-309      12414108  12310260    Related        is related to
# 3  DIRSERVER-32         10493     10001  dependent  is depended upon by
# 4  DIRSERVER-32         10492     10001  dependent  is depended upon by
#
#     type.outward  inwardIssue.id inwardIssue.key  \
# 0  is a clone of             NaN             NaN
# 1     relates to             NaN             NaN
# 2     relates to      12793373.0         MNG-328
# 3   depends upon             NaN             NaN
# 4   depends upon         17793.0    DIRSERVER-56
#
#                                  inwardIssue.summary  inwardIssue.status.id  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# ...

# %%
# drop duplicate rows
issuelinks = issuelinks.drop_duplicates()

# %%
len(issuelinks)
# Out:
# 385278

# %%
issuelinks.head(50)
# Out:
#                key  issuelink.id   type.id     type.name          type.inward  \
# 0       XALANC-524         11181     10020       Cloners         is cloned by
# 1          MNG-309      12414097  12310260       Related        is related to
# 2          MNG-309      12414108  12310260       Related        is related to
# 3     DIRSERVER-32         10493     10001     dependent  is depended upon by
# 4     DIRSERVER-32         10492     10001     dependent  is depended upon by
# 5         MNG-2179      12414685  12310000     Duplicate     is duplicated by
# 6         MNG-2179      12414435  12310000     Duplicate     is duplicated by
# 7      MYFACES-149      12310381  12310000     Duplicate     is duplicated by
# 8        DERBY-634      12313140     10030     Reference        is related to
# 9     ARCHETYPE-53      12415702  12310000     Duplicate     is duplicated by
# 10    HARMONY-2368      12314396  12310000     Duplicate     is duplicated by
# ...

# %%
# len of unique issue keys
len(issuelinks["key"].unique())
# Out:
# 241454

# %%
issuelinks[issuelinks["issuelink.id"] == 10492].values
# Out:
# array([['DIRSERVER-32', 10492, 10001, 'dependent', 'is depended upon by',
#         'depends upon', 17793.0, 'DIRSERVER-56',
#         'Create digester rules to decode all LDAPv3 message types', 6.0,
#         'Closed', 3.0, 'done', 'green', 'Done', 1.0, 'Blocker', 1.0,
#         'A problem which impairs or prevents the functions of the product.',
#         'Bug', False, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan],
#        ['DIRSERVER-56', 10492, 10001, 'dependent', 'is depended upon by',
#         'depends upon', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, 21072.0, 'DIRSERVER-32',
#         'Write a ResultRule', 6.0, 'Closed', 3.0, 'done', 'green',
#         'Done', 3.0, 'Major', 1.0,
#         'A problem which impairs or prevents the functions of the product.',
#         'Bug', False]], dtype=object)
